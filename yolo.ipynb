# %%
import ultralytics
model=ultralytics.YOLO('yolov8n.pt')

# %%
import cv2

result=model(['traffic.jpg','junction.jpg'])
for i in result:
  i.save(filename='result.jpg')
  img=cv2.imread('result.jpg')
  cv2.imshow('Label',img)
  cv2.waitKey(10000)
  cv2.destroyAllWindows()
# Out:
# 0: 640x640 39 cars, 2 buss, 3 trucks, 1 traffic light, 97.5ms
# 1: 640x640 5 persons, 8 cars, 2 buss, 2 traffic lights, 97.5ms
# Speed: 5.4ms preprocess, 97.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
